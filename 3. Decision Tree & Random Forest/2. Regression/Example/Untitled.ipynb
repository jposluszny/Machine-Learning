# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('autos.csv')

# %%
df.head()
# Out:
#    symboling         make fuel-type aspiration num-of-doors   body-style  \
# 0          3  alfa-romero       gas        std          two  convertible
# 1          3  alfa-romero       gas        std          two  convertible
# 2          1  alfa-romero       gas        std          two    hatchback
# 3          2         audi       gas        std         four        sedan
# 4          2         audi       gas        std         four        sedan
#
#   drive-wheels engine-location  wheel-base  length  ...  engine-size  \
# 0          rwd           front        88.6   168.8  ...          130
# 1          rwd           front        88.6   168.8  ...          130
# 2          rwd           front        94.5   171.2  ...          152
# 3          fwd           front        99.8   176.6  ...          109
# 4          4wd           front        99.4   176.6  ...          136
#
#    fuel-system  bore stroke compression-ratio  horsepower peak-rpm  city-mpg  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   make               205 non-null    object
#  2   fuel-type          205 non-null    object
#  3   aspiration         205 non-null    object
#  4   num-of-doors       205 non-null    object
#  5   body-style         205 non-null    object
#  6   drive-wheels       205 non-null    object
#  7   engine-location    205 non-null    object
#  8   wheel-base         205 non-null    float64
#  9   length             205 non-null    float64
#  10  width              205 non-null    float64
#  11  height             205 non-null    float64
#  12  curb-weight        205 non-null    int64
#  13  engine-type        205 non-null    object
#  14  num-of-cylinders   205 non-null    object
#  15  engine-size        205 non-null    int64
# ...

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size        bore      stroke  compression-ratio  \
# count   205.000000   205.000000  205.000000  205.000000         205.000000
# mean   2555.565854   126.907317    3.329171    3.255317          10.142537
# std     520.680204    41.642693    0.270875    0.313598           3.972040
# ...

# %%
df.columns
# Out:
# Index(['symboling', 'make', 'fuel-type', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price'],
#       dtype='object')

# %%
cats = ['symboling', 'make', 'fuel-type', 'aspiration', 'num-of-doors',
       'body-style', 'drive-wheels', 'engine-location','engine-type', 
        'num-of-cylinders','engine-size', 'fuel-system']

# %%
dfd = pd.get_dummies(df, columns=cats, drop_first = True)

# %%
dfd.head()
# Out:
#    wheel-base  length  width  height  curb-weight  bore  stroke  \
# 0        88.6   168.8   64.1    48.8         2548  3.47    2.68
# 1        88.6   168.8   64.1    48.8         2548  3.47    2.68
# 2        94.5   171.2   65.5    52.4         2823  2.68    3.47
# 3        99.8   176.6   66.2    54.3         2337  3.19    3.40
# 4        99.4   176.6   66.4    54.3         2824  3.19    3.40
#
#    compression-ratio  horsepower  peak-rpm  ...  engine-size_304  \
# 0                9.0       111.0      5000  ...            False
# 1                9.0       111.0      5000  ...            False
# 2                9.0       154.0      5000  ...            False
# 3               10.0       102.0      5500  ...            False
# 4                8.0       115.0      5500  ...            False
#
#    engine-size_308  engine-size_326  fuel-system_2bbl  fuel-system_4bbl  \
# 0            False            False             False             False
# ...

# %%
X = dfd.drop('price', axis=1)
y = dfd.price

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tr = DecisionTreeRegressor()

# %%
tr.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
predictions = tr.predict(X_test)
predictions
# Out:
# array([24565. , 22625. ,  8949. , 12170. , 35056. ,  7299. ,  7898. ,
#         8195. ,  8949. ,  7995. , 13645. ,  8058. , 14997.5, 10898. ,
#        31600. ,  7609. ,  5399. , 14869. ,  6989. ,  9279. , 10245. ,
#        13499. ,  7299. ,  5572. ,  7609. , 23875. ,  9989. , 16515. ,
#         7198. , 15985. , 35056. ,  6692. ,  8778. , 11900. ,  7957. ,
#        22470. ,  9279. , 13645. , 13207. , 14869. ,  8013. ,  8921. ,
#        16695. ,  8778. ,  6938. ,  7895. ,  7609. ,  7775. , 17950. ,
#        12764. ,  5399. , 15998. ,  5572. , 10898. ,  7198. , 13645. ,
#         9989. , 13645. , 33278. ,  5572. , 11694. , 18399. , 10898. ,
#        12764. , 13845. ,  6095. , 14997.5,  6938. ])

# %%
ax = sns.scatterplot(x=y_test, y=predictions)
ax.set_ylabel('Predictions')
ax.set_xlabel('Price')
# Out:
# Text(0.5, 0, 'Price')

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import root_mean_squared_error

# %%
mean_absolute_error(y_test, predictions)
# Out:
# 2305.75

# %%
mean_squared_error(y_test, predictions)
# Out:
# 15259595.654411765

# %%
root_mean_squared_error(y_test, predictions)
# Out:
# 3906.3532424003547

# %%
sns.histplot((y_test - predictions), bins=50, kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
tr_import = tr.feature_importances_
importances = pd.DataFrame(tr_import, index=X_train.columns, columns=['Importance']).sort_values(by='Importance', ascending=False)
importances
# Out:
#                     Importance
# curb-weight           0.560579
# highway-mpg           0.265610
# engine-size_194       0.063655
# length                0.041636
# body-style_hardtop    0.012671
# ...                        ...
# engine-type_ohcv      0.000000
# engine-type_ohcf      0.000000
# engine-type_l         0.000000
# engine-type_dohcv     0.000000
# fuel-system_spfi      0.000000
#
# [110 rows x 1 columns]

# %%
ax = sns.barplot(x=importances.head().Importance, y=importances.head().index)
ax.set_ylabel('Feature')
# Out:
# Text(0, 0.5, 'Feature')

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rr = RandomForestRegressor()

# %%
rr.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
predictions = rr.predict(X_test)

# %%
mean_absolute_error(y_test, predictions)
# Out:
# 1868.0546200980398

# %%
mean_squared_error(y_test, predictions)
# Out:
# 10261485.518903278

# %%
root_mean_squared_error(y_test, predictions)
# Out:
# 3203.355353204399

# %%
ax = sns.scatterplot(x=y_test, y=predictions)
ax.set_xlabel('Price')
ax.set_ylabel('Predictions')
# Out:
# Text(0, 0.5, 'Predictions')

# %%
sns.histplot((y_test - predictions), kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
importances = rr.feature_importances_

# %%
importances_df = pd.DataFrame(importances, index=X_train.columns, columns=['Importance']).sort_values(by='Importance', ascending=False)

# %%
importances_df
# Out:
#                         Importance
# curb-weight               0.481677
# highway-mpg               0.180045
# horsepower                0.098034
# city-mpg                  0.048350
# num-of-cylinders_four     0.029644
# ...                            ...
# engine-size_308           0.000000
# engine-size_140           0.000000
# engine-size_173           0.000000
# fuel-system_mfi           0.000000
# num-of-cylinders_three    0.000000
#
# [110 rows x 1 columns]

# %%
ax = sns.barplot(x=importances_df.head(10).Importance, y=importances_df.head(10).index)
ax.set_ylabel('Feature')
# Out:
# Text(0, 0.5, 'Feature')

# %%
from sklearn.tree import export_graphviz
export_graphviz(rr.estimators_[0], 
                out_file='tree.dot', 
                feature_names = X.columns,
                filled = True)
